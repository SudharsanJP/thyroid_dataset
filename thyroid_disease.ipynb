# %%
#project details
import simple_colors
print(simple_colors.magenta("\033[1m" + """                                task            :    thyroid disease 
                                learner name    :    J.Sudharsan
                                institute       :    GUVI""" + "\033[0m"))
# Out:
#                                 task            :    thyroid disease
#                                 learner name    :    J.Sudharsan
#                                 institute       :    GUVI

# %%
import pandas as pd

# %%
#) thyroid disease dataset
df = pd.read_csv(r"D:\Sudharsan\Guvi_Data science\DS101_Sudharsan\Mainboot camp\capstone project\thyrad_disease\thyroid_diff.csv")
df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
#) null values
df.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
#)columns
df.columns
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred'],
#       dtype='object')

# %%
#) thyroid function column
df['Thyroid Function'].unique()
# Out:
# array(['Euthyroid', 'Clinical Hyperthyroidism', 'Clinical Hypothyroidism',
#        'Subclinical Hyperthyroidism', 'Subclinical Hypothyroidism'],
#       dtype=object)

# %%
#) response column
df['Response'].unique()
# Out:
# array(['Indeterminate', 'Excellent', 'Structural Incomplete',
#        'Biochemical Incomplete'], dtype=object)

# %%
#) risk column
df['Risk'].unique()
# Out:
# array(['Low', 'Intermediate', 'High'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
#)boxplot
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x = "Thyroid Function",y="Age",hue="Recurred")
plt.show()

# %%
#)boxplot
plt.figure(figsize=(15,6))
sns.violinplot(data=df,x = "Thyroid Function",y="Age",hue="Recurred")
plt.show()

# %%
#)boxplot
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x = "Thyroid Function",y="Age",hue="Risk")
plt.show()

# %%
#)boxplot
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x = "Thyroid Function",y="Age",hue="Gender")
plt.show()

# %%
df['Stage'].unique()
# Out:
# array(['I', 'II', 'IVB', 'III', 'IVA'], dtype=object)

# %%
#)boxplot
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x = 'Stage',y="Age",hue="Gender")
plt.show()

# %%
#)dummies
df = pd.get_dummies(df,columns=['Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
       'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
       'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response','Recurred'],drop_first=True)

# %%
df
# Out:
#      Age  Gender_M  Smoking_Yes  Hx Smoking_Yes  Hx Radiothreapy_Yes  \
# 0     27     False        False           False                False
# 1     34     False        False            True                False
# 2     30     False        False           False                False
# 3     62     False        False           False                False
# 4     62     False        False           False                False
# ..   ...       ...          ...             ...                  ...
# 378   72      True         True            True                 True
# 379   81      True         True           False                 True
# 380   72      True         True            True                False
# 381   61      True         True            True                 True
# 382   67      True         True           False                False
#
#      Thyroid Function_Clinical Hypothyroidism  Thyroid Function_Euthyroid  \
# ...

# %%
#) Ml models
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score


X =df.drop(['Recurred_Yes'],axis=1)
y = df['Recurred_Yes']

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

models = [LogisticRegression(),
          KNeighborsClassifier(),
          SVC(),
          DecisionTreeClassifier(),
          RandomForestClassifier(),
          AdaBoostClassifier(),
          GradientBoostingClassifier()
         ]
for model in models:
        model.fit(x_train,y_train)
        train_pred = model.predict(x_train)
        test_pred = model.predict(x_test)
        print(f"*******{type(model).__name__}*******")
        print('*******Train*******')
        print(f"Accuracy: {accuracy_score(y_train,train_pred)}")
        print(f"Precision: {precision_score(y_train,train_pred)}")
        print(f"Recall: {recall_score(y_train,train_pred)}")
        print(f"F1 Score: {f1_score(y_train,train_pred)}")
        print('*******Test*******')
        print(f"Accuracy: {accuracy_score(y_test,test_pred)}")
        print(f"Precision: {precision_score(y_test,test_pred)}")
        print(f"Recall: {recall_score(y_test,test_pred)}")
        print(f"F1 Score: {f1_score(y_test,test_pred)}")
        print("\n\n")
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# *******LogisticRegression*******
# *******Train*******
# Accuracy: 0.9738562091503268
# Precision: 0.9873417721518988
# Recall: 0.9176470588235294
# F1 Score: 0.9512195121951219
# *******Test*******
# Accuracy: 0.961038961038961
# Precision: 0.9545454545454546
# Recall: 0.9130434782608695
# F1 Score: 0.9333333333333333
#
#
#
# *******KNeighborsClassifier*******
# *******Train*******
# Accuracy: 0.9215686274509803
# ...
